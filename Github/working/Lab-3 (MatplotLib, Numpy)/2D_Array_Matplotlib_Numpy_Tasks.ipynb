# %% [markdown]
# <a href="https://colab.research.google.com/github/ibtisamafzal/Artificial-Intelligence-FA24/blob/main/2D_Array_Matplotlib_Numpy_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Numpy Array**

# %%
# !pip install numpy

# %%
import numpy as np

# %% [markdown]
# **2D Array = Lowest and Highest Temperature of the day**

# %%
temperatures = np.array([
    [27.5, 45.5],
    [36.5, 42.6],
    [33.7, 50.1],
    [30.5, 38.2]
    ])
print(temperatures)
# Out:
# [[27.5 45.5]
#  [36.5 42.6]
#  [33.7 50.1]
#  [30.5 38.2]]

# %%
import matplotlib.pyplot as plt

# %%
average_temp = np.mean(temperatures[:,0])
average_temp_2 = np.mean(temperatures[:,1])

# %%
print(average_temp)
print(average_temp_2)
# Out:
# 32.05
# 44.099999999999994

# %%
overall_average_temp= (average_temp + average_temp_2)/2

# %%
print (overall_average_temp)
# Out:
# 38.074999999999996

# %%
plt.figure(figsize=(10,5))
plt.plot(temperatures[:,0], marker="o", linestyle="--", color="blue",label="Low Temperature")
plt.plot(temperatures[:,1], marker="o", linestyle="--", color="orange",label="High Temperature")
plt.plot(overall_average_temp, marker="o", color="green",label="Average Temperature")
plt.title("Temperature Report of the week")
plt.ylabel("Temperature")
plt.xlabel("Days")
plt.legend()
plt.grid()
plt.show()
