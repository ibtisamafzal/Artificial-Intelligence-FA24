# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/drive/MyDrive/Colab Notebooks/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d telikaramu/covid-19-vaccination-effects -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/telikaramu/covid-19-vaccination-effects
# License(s): CC0-1.0
# ...
#   0% 0.00/43.4k [00:00<?, ?B/s]
# 100% 43.4k/43.4k [00:00<00:00, 3.85MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/covid-19-vaccination-effects.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/A project report on corona vaccination side effects.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 30 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Gender                                220 non-null    int64
#  1   Age                                   220 non-null    int64
#  2   eduction                              220 non-null    int64
#  3   occupation                            220 non-null    int64
#  4   area of Hyderabad                     220 non-null    int64
#  5   doses of the COVID-19 vaccine         220 non-null    int64
#  6   Which COVID-19 vaccine                220 non-null    int64
#  7   Which COVID-19 vaccine                220 non-null    int64
#  8   Feeling lazy.                         220 non-null    int64
#  9   Lost fear about COVID-19.             220 non-null    int64
#  10  Feeling stress & anxiety.             220 non-null    int64
# ...
