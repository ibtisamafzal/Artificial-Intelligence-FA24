# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !kaggle datasets download -d abdullah0a/student-dropout-analysis-and-prediction-dataset -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abdullah0a/student-dropout-analysis-and-prediction-dataset
# License(s): MIT
# ...
#   0% 0.00/11.3k [00:00<?, ?B/s]
# 100% 11.3k/11.3k [00:00<00:00, 1.03MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/student-dropout-analysis-and-prediction-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/student dropout.csv')
df.head()
# Out:
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 0                 4    at_home    teacher  ...         3         4
# 1                 1    at_home      other  ...         3         3
# 2                 1    at_home      other  ...         3         2
# 3                 2     health   services  ...         2         2
# 4                 3      other      other  ...         3         2
#
#    Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/drive/MyDrive/Colab Notebooks/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
