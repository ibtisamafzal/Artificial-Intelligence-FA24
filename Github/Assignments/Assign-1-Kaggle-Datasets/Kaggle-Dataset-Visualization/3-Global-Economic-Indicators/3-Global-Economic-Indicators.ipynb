# %%
# !mkdir -p ~/.kaggle
# !cp "/content/drive/MyDrive/Colab Notebooks/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d heidarmirhajisadati/global-economic-indicators-dataset-2010-2023 -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/heidarmirhajisadati/global-economic-indicators-dataset-2010-2023
# License(s): MIT
# ...
#   0% 0.00/8.72k [00:00<?, ?B/s]
# 100% 8.72k/8.72k [00:00<00:00, 917kB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/e-commerce-customer-behavior-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/economic_indicators_dataset_2010_2023.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-11c8e9c98a66> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/economic_indicators_dataset_2010_2023.csv')
#       3 df.head()
#
# ...
