# %%
# !kaggle datasets download -d huzzefakhan/zameencom-property-data-pakistan -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/huzzefakhan/zameencom-property-data-pakistan
# License(s): CC0-1.0
# ...
#  64% 11.0M/17.1M [00:00<00:00, 43.3MB/s]
# 100% 17.1M/17.1M [00:00<00:00, 55.5MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/zameencom-property-data-pakistan.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Property_with_Feature_Engineering.csv')
df.head()
# Out:
#    property_id  location_id  \
# 0       347795            8
# 1       482892           48
# 2       555962           75
# 3       562843         3821
# 4       686990         3522
#
#                                             page_url property_type      price  \
# 0  https://www.zameen.com/Property/lahore_model_t...         House  220000000
# 1  https://www.zameen.com/Property/lahore_multan_...         House   40000000
# 2  https://www.zameen.com/Property/eden_eden_aven...         House    9500000
# 3  https://www.zameen.com/Property/gulberg_2_gulb...         House  125000000
# 4  https://www.zameen.com/Property/allama_iqbal_t...         House   21000000
#
#    price_bin           location    city province_name  \
# 0  Very High         Model Town  Lahore        Punjab
# 1  Very High        Multan Road  Lahore        Punjab
# 2        Low               Eden  Lahore        Punjab
# 3  Very High            Gulberg  Lahore        Punjab
# ...
