# %%
# !kaggle datasets download -d zusmani/pakistan-toshakhana-files -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/zusmani/pakistan-toshakhana-files
# License(s): CC0-1.0
# ...
#   0% 0.00/1.45M [00:00<?, ?B/s]
# 100% 1.45M/1.45M [00:00<00:00, 59.3MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/pakistan-toshakhana-files.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Toshakhana Files 2.xlsx')
df.head()
# Out:
#   GIFTS RECORD IN TOSHAKHANA SINCE 2002\n2002 Unnamed: 1  \
# 0                                       S.No.        NaN
# 1                                           1        NaN
# 2                                           2        NaN
# 3                                           3        NaN
# 4                                           4        NaN
#
#                            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                     Detail of Gifts        NaN        NaN        NaN
# 1          Two   small   silver Bowls        NaN        NaN        NaN
# 2              One Pilot Pen with ink        NaN        NaN        NaN
# 3                     One silver vase        NaN        NaN        NaN
# 4  One    (decoration) folding Screen        NaN        NaN        NaN
#
#                                           Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                                  Name of Recipient        NaN        NaN
# ...
