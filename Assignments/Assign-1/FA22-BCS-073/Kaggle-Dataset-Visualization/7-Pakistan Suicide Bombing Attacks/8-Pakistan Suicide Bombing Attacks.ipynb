# %%
# !kaggle datasets download -d zusmani/pakistansuicideattacks -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/zusmani/pakistansuicideattacks
# License(s): CC0-1.0
# ...
#   0% 0.00/67.5k [00:00<?, ?B/s]
# 100% 67.5k/67.5k [00:00<00:00, 4.74MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/pakistansuicideattacks.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PakistanSuicideAttacksVer11.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-5cdfc96108d0> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PakistanSuicideAttacksVer11.csv')
#       3 df.head()
#
# ...
