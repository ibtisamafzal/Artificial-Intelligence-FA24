# %%
# !kaggle datasets download -d zusmani/predict-pakistan-elections-2018 -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/zusmani/predict-pakistan-elections-2018
# License(s): copyright-authors
# ...
#  99% 46.0M/46.5M [00:01<00:00, 44.6MB/s]
# 100% 46.5M/46.5M [00:01<00:00, 38.1MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/predict-pakistan-elections-2018.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Political Parties in 2018 Elections-updated.csv')
df.head()
# Out:
#                    Name of Political Party       Symbol Acronym
# 0                Aam Admi Tehreek Pakistan          Mug    AATP
# 1                           Aam Awam Party  Wheat Bunch     AAP
# 2                   Aam Log Party Pakistan          Hut    ALPP
# 3  All Pakistan Minority Movement Pakistan      Giraffe   APMMP
# 4               All Pakistan Muslim League        Eagle    APML
