# %%
# !kaggle datasets download -d zusmani/pakistandroneattacks -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.17 / client 1.6.14)
# Dataset URL: https://www.kaggle.com/datasets/zusmani/pakistandroneattacks
# License(s): CC0-1.0
# pakistandroneattacks.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/pakistansuicideattacks.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')
