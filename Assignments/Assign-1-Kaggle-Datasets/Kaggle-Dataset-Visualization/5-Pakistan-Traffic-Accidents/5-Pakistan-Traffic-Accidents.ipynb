# %%
# !kaggle datasets download -d mfaisalqureshi/pakistan-traffic-accident-dataset -p "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mfaisalqureshi/pakistan-traffic-accident-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/1.47k [00:00<?, ?B/s]
# 100% 1.47k/1.47k [00:00<00:00, 102kB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/pakistan-traffic-accident-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/traffic-accidents-annual-.csv')
df.head()
# Out:
#   *- Islamabad Included. Unnamed: 1                 Unnamed: 2  \
# 0                    NaN       Year  Total number of accidents
# 1               Pakistan    2008-09                       9496
# 2               Pakistan    2009-10                       9747
# 3               Pakistan    2010-11                       9723
# 4               Pakistan    2011-12                       9140
#
#         Unnamed: 3           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  Fatal Accidents  Non-Fatal Accidents     Killed    Injured
# 1             4145                 5351       4907      11037
# 2             4378                 5369       5280      11173
# 3             4280                 5443       5271      11383
# 4             3966                 5174       4758      10145
#
#                           Unnamed: 7
# 0  Total number of vehicles involved
# 1                              10322
# 2                              10496
# 3                              10822
# ...
